# %% [markdown]
# ### EXTRAER TRABAJOS DE COMPUTRABAJO APLICANDO TECNICAS DE WEBSCRAPING

# %%
# !pip install webdriver_manager
# Out:
# Collecting webdriver_manager
#   Obtaining dependency information for webdriver_manager from https://files.pythonhosted.org/packages/b5/b5/3bd0b038d80950ec13e6a2c8d03ed8354867dc60064b172f2f4ffac8afbe/webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from webdriver_manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from webdriver_manager) (1.1.0)
# Requirement already satisfied: packaging in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from webdriver_manager) (24.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver_manager) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver_manager) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver_manager) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\appdata\local\programs\python\python311\lib\site-packages (from requests->webdriver_manager) (2023.11.17)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver_manager
# Successfully installed webdriver_manager-4.0.2
# [notice] A new release of pip is available: 23.2.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import time
from selenium.webdriver.common.by import By
from selenium import webdriver


from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# %%
def iniciar_busqueda(departamento, url='https://pe.computrabajo.com/'):
    """
    Inicia sesión en la página de ComputraBajo y realiza una búsqueda inicial por departamento.
    
    :param departamento: Nombre del departamento para la búsqueda
    :type departamento: str
    :param url: URL del sitio de ComputraBajo (opcional)
    :type url: str
    :return: None
    :rtype: None
    """
    driver.get(url)
    time.sleep(5)
    
    # Buscar el departamento
    search_box = driver.find_element(By.ID, 'place-search-input')
    search_box.send_keys(departamento)
    
    # Hacer clic en el botón de búsqueda
    search_button = driver.find_element(By.ID, 'search-button')
    search_button.click()
    
    # Tiempo de espera para que cargue la página de resultados
    time.sleep(3)
    
    return None

# %%
def obtener_ultima_url(log_file='ultimo_scraping.txt'):
    """
    Obtiene la última URL procesada del archivo de log.
    
    :param log_file: Ruta al archivo de log
    :type log_file: str
    :return: La última URL procesada o None si no existe
    :rtype: str or None
    """
    try:
        with open(log_file, 'r', encoding='utf-8') as file:
            lines = file.readlines()
            if lines:
                return lines[-1].strip()
    except FileNotFoundError:
        print(f"No se encontró el archivo de log {log_file}. Se iniciará desde el principio.")
    return None

# %%
def guardar_ultima_url(url, log_file='ultimo_scraping.txt'):
    """
    Guarda la URL actual en el archivo de log.
    
    :param url: URL a guardar
    :type url: str
    :param log_file: Ruta al archivo de log
    :type log_file: str
    :return: None
    :rtype: None
    """
    with open(log_file, 'a', encoding='utf-8') as file:
        file.write(f"{url}\n")

# %%
def main():
    # Configurar el webdriver
    chrome_options = Options()
    chrome_options.add_argument("--start-maximized")
    # chrome_options.add_argument("--headless")
    
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=chrome_options)
    
    # Archivos para almacenar datos y logs
    output_file = 'job_details.json'
    log_file = 'ultimo_scraping.txt'
    
    # Cargar datos previos del JSON
    job_details = {}
    try:
        with open(output_file, 'r', encoding='utf-8') as file:
            content = file.read().strip()
            if content:
                job_details = json.loads(content)
                print(f"Se cargaron {len(job_details)} registros previos del archivo JSON.")
            else:
                print("El archivo JSON existe pero está vacío. Se inicializará con un diccionario vacío.")
    except FileNotFoundError:
        print("No se encontró un archivo previo. Se creará uno nuevo.")
    
    # Obtener la última URL procesada o iniciar búsqueda si no hay
    ultima_url = obtener_ultima_url(log_file)
    
    if ultima_url:
        print(f"Continuando desde la última URL procesada: {ultima_url}")
        driver.get(ultima_url)
        time.sleep(5)
    else:
        print("Iniciando nueva búsqueda desde el principio")
        iniciar_busqueda('Lima')
    
    while True:
        current_url = driver.current_url
        print(f"Procesando página: {current_url}")
        
        try:
            try:
                popup = driver.find_element(By.ID, 'pop-up-webpush-sub')
                close_button = popup.find_element(By.TAG_NAME, 'button')
                close_button.click()
                print("Pop-up cerrado.")
            except:
                print("No se encontró el pop-up.")
            
            # Extraer ofertas de trabajo
            job_offers = driver.find_elements(By.CLASS_NAME, 'box_offer')
            
            print(f"Encontradas {len(job_offers)} ofertas en esta página")
            
            for offer in job_offers:
                try:
                    title_element = offer.find_element(By.CLASS_NAME, 'js-o-link')
                    job_title = title_element.text
                    
                    if job_title in job_details:
                        print(f"Oferta ya procesada: {job_title}")
                        continue
                    
                    offer.click()
                    time.sleep(2)
                    
                    detail_element = driver.find_element(By.CLASS_NAME, 'box_detail')
                    job_details[job_title] = detail_element.get_attribute('innerHTML')
                    
                    print(f"Oferta extraída: {job_title}")
                    
                    driver.back()
                    time.sleep(2)
                except Exception as e:
                    print(f"Error al procesar una oferta: {e}")
            
            with open(output_file, 'w', encoding='utf-8') as file:
                json.dump(job_details, file, ensure_ascii=False, indent=4)
            
            print(f"Total de ofertas guardadas: {len(job_details)}")
            
            guardar_ultima_url(current_url, log_file)
            
            next_button = driver.find_element(By.CLASS_NAME, 'b_primary.w48.buildLink.cp')
            
            if next_button:
                next_url = next_button.get_attribute('href')
                print(f"Pasando a la siguiente página: {next_url}")
                next_button.click()
                time.sleep(5)
            else:
                print("No hay más páginas.")
                break
        
        except Exception as e:
            print(f"Error general en la página {current_url}: {e}")
            # Guardar progreso antes de salir debido a un error
            with open(output_file, 'w', encoding='utf-8') as file:
                json.dump(job_details, file, ensure_ascii=False, indent=4)
            print(f"Se guardaron los datos antes de finalizar por error. Total: {len(job_details)}")
            break
    
    driver.quit()
    print("Proceso completado.")

# %%
if __name__ == "__main__":
    main()
# Out:
# Se cargaron 2353 registros previos del archivo JSON.
# Continuando desde la última URL procesada: https://pe.computrabajo.com/empleos-en-lima?p=164
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=164
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Vendedor de Campo con Movilidad LIMA ESTE Turno de 1pm a 10 pm Gana hasta S/2370
# Oferta ya procesada: 20 Vendedores o Mercaderista de Campo LIMA ESTE Canal Tradicional GANA S/1900 Comisión Fija
# Oferta ya procesada: Impulsadora/Consultora/Productos de belleza/Campaña/Aruma Real Plaza Villa Maria del triunfo
# Oferta ya procesada: Impulsadora/Consultora/Productos de belleza/Campaña/Aruma La Rambla Brasil
# Oferta ya procesada: Atención al cliente
# Oferta ya procesada: Operarios de Producción
# Oferta ya procesada: Auxiliar administrativo contable
# Oferta ya procesada: Asesor de Retenciones Call Center/ Part Time Tarde/ Sede Independencia/Con o Sin Experiencia
# Oferta ya procesada: Asistente de recursos humanos
# Oferta ya procesada: Operarios de Planta y Almacen
# Oferta ya procesada: Vendedor Horecas
# Oferta ya procesada: Almacenero
# Oferta ya procesada: Verificador (a) / Planilla Completa / Con experiencia
# Oferta ya procesada: Planilla completa!! Asesores de ventas / Con o sin experiencia / Full Mañana !!
# Oferta ya procesada: Asistente de Costos y Presupuestos : Área Comercial
# Oferta ya procesada: Solo Atención al Cliente La positiva / Sueldo 1300 / Full time en Santa Anita
# Oferta ya procesada: Solo Atención al cliente La positiva / Sueldo 1300 / Full time Presencial en Santa Anita
# Oferta ya procesada: Sólo Atención al cliente Falabella Perú voz y chat / Descanso fijo Domingo / Presencial Sede Ate !
# Oferta ya procesada: Asistente de Tienda / Cafetería
# Oferta ya procesada: Mozo / Azafata
# Total de ofertas guardadas: 2353
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=165
# Pop-up cerrado.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Supervisor de campo última milla
# Oferta extraída: Atención al Cliente / Full Time PM/ Gana hasta S/ 1680
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="8953BCB1A2C8FDB461373E686DCF3405" data-blind="false" id="8953BCB1A2C8FDB461373E686DCF3405" data-lc="ListOffers-Score-2" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta ya procesada: Solo 7 días de capa/planilla completa/full time tarde / Asesor Comercial /independencia
# Oferta ya procesada: Trabaja solo de lunes a viernes !/ Con o Sin Experiencia/ Turno Mañana / Planilla Completa
# Oferta ya procesada: Ingreso Directo!! Call Center Personal Sin Experiencia/Trabaja de Lunes a Viernes Turno Mañana
# Oferta ya procesada: Trabaja De Lunes a Viernes / Personal Sin Experiencia/ Planilla Completa / Pagos Quincenales
# Oferta ya procesada: !Ejecutivo de ventas Con o Sin Experiencia!Ingreso a planilla completa/ Chorrillos/ Sueldo basico
# Oferta ya procesada: ¡Urgente Chorrillos! SOLO atención al cliente/Con o Sin Exp /Planilla Completa /Turno a Elegir/Claro
# Oferta ya procesada: SOLO Atención al Cliente / Call Center /Asesores para Aerolínea /Turno Mañana ¡Trabaja 7h 15 min!
# Oferta ya procesada: Fotógrafo/a y Videógrafo/a de Moda
# Oferta extraída: Promotoras/Vendedoras de Campo/Marca Líder en Cuidado Personal/ Ruta Lima Centro(Barrio Chino)
# Oferta ya procesada: Ventas presenciales/ call center/ planilla completa
# Oferta ya procesada: Chorrillos!!SOLO Atención al cliente/Con o Sin Experiencia /Planilla Completa /Turno a Elegir/Claro
# Oferta ya procesada: Asesor de Entel/comisiones ilimitadas/con o sin experiencia
# Oferta ya procesada: Mercaderista/ Repartidor para Movistar / En Lima Sur / SJM / VMT/ VES
# Oferta ya procesada: Asesor de ventas/comisiones ilimitadas/con o sin experiencia
# Oferta ya procesada: Teleoperador Atención al Cliente Chat y Voz Falabella /Ingreso Directo /Planilla
# Oferta ya procesada: Teleoperador de calla center/ planilla completa/comisiones ilimitadas
# Oferta ya procesada: Call Center ¡Trabaja desde Casa! Asesor de Ventas / Sueldo fijo S/.1130 + Comisiones
# Total de ofertas guardadas: 2355
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=166
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Fotógrafo/a y Videógrafo/a de Moda
# Oferta ya procesada: Promotoras/Vendedoras de Campo/Marca Líder en Cuidado Personal/ Ruta Lima Centro(Barrio Chino)
# Oferta ya procesada: Ventas presenciales/ call center/ planilla completa
# Oferta ya procesada: Chorrillos!!SOLO Atención al cliente/Con o Sin Experiencia /Planilla Completa /Turno a Elegir/Claro
# Oferta ya procesada: Asesor de Entel/comisiones ilimitadas/con o sin experiencia
# Oferta ya procesada: Mercaderista/ Repartidor para Movistar / En Lima Sur / SJM / VMT/ VES
# Oferta ya procesada: Asesor de ventas/comisiones ilimitadas/con o sin experiencia
# Oferta ya procesada: Teleoperador Atención al Cliente Chat y Voz Falabella /Ingreso Directo /Planilla
# Oferta ya procesada: Teleoperador de calla center/ planilla completa/comisiones ilimitadas
# Oferta ya procesada: Call Center ¡Trabaja desde Casa! Asesor de Ventas / Sueldo fijo S/.1130 + Comisiones
# Oferta ya procesada: Konecta ¡Únete a nuestro equipo! Solo Atención al Cliente Call Center / Descanso Sábado o Domingos
# Oferta extraída: Promotor comercial
# Oferta ya procesada: SIN Experiencia / SOLO 42 Horas Semanales / Santa Anita / Call Center Claro Ventas
# Oferta ya procesada: Horarios flexibles/ Asesor de Atención al Cliente / Turno Tarde o noche / CON o SIN Exper/
# Oferta ya procesada: Ingresa Hoy! A T C y Cross/Trabaja 44H semanales/Turno madrugada/Publico Español /Movilid!
# Oferta ya procesada: Asesor de ventas ¡Postula YAA!!! Gana S/1300 a mas! + Bonos + Comisiones / Con o Sin Experiencia!
# Oferta ya procesada: Promotora/Impulsadora Minorista/Perfumería Andaly/SJM/Cuidado Personal
# Oferta ya procesada: Trabajo Remoto !! Asesores Portabilidad Claro / Descanso fijo los Domingos
# Oferta ya procesada: Impulsadora de Ventas Perfumería / Barrio Chino / Rubro Belleza/ Planilla completa
# Oferta ya procesada: Impulsadora Perfumería Mayorista/ Barrio Chino / Cuidado Personal / Planilla completa + Beneficios
# Total de ofertas guardadas: 2356
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=167
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Impulsadora Perfumeria Mayorista / Barrio Chino / Planilla completa
# Oferta ya procesada: Atención al cliente Call Center Ripley /No Ventas, turno mañana Trabaja 5 dias a la semana S/1200/
# Oferta ya procesada: Trabaja desde casa/ Sin experiencia/ damos pc + internet/ Sueldo basico 1200 + bono de luz M
# Oferta ya procesada: Santa Anita ¡Porta Asesor Claro 42horas semanal full mañana!!sin experiencia ¡Capa 35 por dia¡
# Oferta extraída: Ejecutivo Claro ventas 42horas sueldo fijo/comisiones/ sede Santa Anita !9am a 5pm descanso domingo¡
# Oferta extraída: Asistente de Trade Marketing (RR HH) Cuenta Consumo Masivo
# Oferta ya procesada: Vendedores de Campo LIMA ESTE Gana hasta S/3000 Bebidas Canal Tradicional
# Oferta ya procesada: Convocatoria Abierta/ Trabaja 6hrs y Gana S/1200 + Descansa Domingos + Bonos + Planilla Completa
# Oferta ya procesada: Atención al Cliente BBVA/Descanso Domingo con Horario de Oficina/Presencial en el Centro de Lima
# Oferta ya procesada: BBVA: ¡Atención al cliente! Turno Tarde / Con o Sin Experiencia / Sede Cercado de Lima
# Oferta ya procesada: Asistente de Almacén Huachipa
# Oferta ya procesada: ¡¡Trabaja para el BCP (Asesor Bancario)!! C/Sin Experiencia/Sede Ov. Santa Anita
# Oferta ya procesada: BBVA: Atiende por CHAT hasta S/. 1300 todos los meses!! / SOLO Atención al Cliente, NO ventas
# Oferta ya procesada: Solo Atención al Cliente/Trabaja solo 7hrs con 15min+45 de break/Sueldo+incentivos+comisiones
# Oferta ya procesada: Banco Ripley Banca Telefónica (call center) SOLO Atención al cliente / Sector Financiero
# Oferta ya procesada: Ingreso Directo SIN OJT! Asesores Entel c/s experiencia / SOLO 6H AL DÍA / Libre Domingo
# Oferta ya procesada: Solo Atención al Cliente/Trabaja solo 7hrs con 15min+45 de break/Sueldo+incentivos+comisiones
# Oferta ya procesada: Solo Atención al Cliente/Trabaja solo 7hrs con 15min+45 de break/Sueldo+incentivos+comisiones
# Oferta ya procesada: ¡¡Trabaja desde Casa!! Asesores Call Center C/S Exp/ Fijo 1220+ Comisiones /Te damos PC/Laptop
# Oferta ya procesada: Trabaja en Atento/Asesor de venta empresarial/Con o sin experiencia/Descansa domingo/42h semanales
# Total de ofertas guardadas: 2358
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=168
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Trabaja en Atento/Asesor de venta empresarial/Con o sin experiencia/Descansa domingo/42h semanales
# Oferta extraída: Gana hasta S/1,330!!!Trabaja 7hrs con 15min+45 de break/Con o sin experiencia/Sede Cercado de Lima
# Oferta ya procesada: Solo Atención al Cliente/Trabaja solo 7hrs con 15min+45 de break/Sueldo+incentivos+comisiones
# Oferta ya procesada: ¡Trabaja de Lunes a Viernes! +Firma de contrato en 4 días+Turno Mañana + Sueldo Fijo C/S Experiencia
# Oferta ya procesada: Trabaja de Lunes a Sábado/Banco BBVA en el Centro de Lima/Presencial con Descanso Domingo
# Oferta ya procesada: Asistente Comercial
# Oferta ya procesada: Trabaja solo 6 horas! Ten tus tardes libres!
# Oferta ya procesada: Ingreso Inmediato! Agentes de seguridad / Lima y Callao / Planilla Completa
# Oferta ya procesada: ¡¡Trabaja 6 horas!! Sueldo fijo/ Comisiones ilimitadas
# Oferta ya procesada: Full time AM / Planilla Completa / ATC / Gana hasta S/1600/ Presencial en San Isidro
# Oferta ya procesada: Trabaja solo 6 horas! Ten tus tardes libres! RxH o Planilla! Tú decides!
# Oferta ya procesada: Promotora full time Zona Norte
# Oferta ya procesada: Ingreso INME DIAT O/ Agentes Telefónicos Entel / Atencion al cliente
# Oferta ya procesada: Konecta: Asesores de Agendamiento con descanso Domingo/Sueldo+Variables+Bono de Permanencia
# Oferta extraída: Trabaja desde casa y capacitate!! Portabilidad Claro ¡9am a 6pm! descanso domingo
# Oferta ya procesada: Sede Santa Anita!!Asesor ventas Claro empresas/ solo 42h. semanal ¡Sin experiencia!
# Oferta ya procesada: Trabaja Recibiendo Llamadas /Agentes Telefónicos Atención al cliente ENT EL!
# Oferta extraída: Movistar / Experta en Reclutamiento y selección de personal / Sede San Isidro
# Oferta ya procesada: Operarios limpieza con experiencia para trabajar cerca al Jockey Plaza
# Oferta ya procesada: Konecta ¡Únete a nuestro equipo! Solo Atención al Cliente Call Center / Descanso Sábado o Domingos
# Total de ofertas guardadas: 2361
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=169
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Ventas Entel / MINI FULL / Ingreso Directo SIN OJT /SOLO 6hrs y gana ¡1300 fijo + comisiones y más
# Oferta ya procesada: Movistar / Experta en Reclutamiento y selección de personal / Sede Lima Norte
# Oferta ya procesada: Movistar / Experta en Reclutamiento y selección de personal / Sede Los Olivos
# Oferta ya procesada: Movistar / Experta en Reclutamiento y selección de personal / Sede Santa Anita Ate
# Oferta ya procesada: Movistar / Experta en Reclutamiento y selección de personal / Sede Los Olivos
# Oferta ya procesada: Asesor de Atención al cliente inbound/ Madrugada/ Básico S/1300+ Bono nocturno + Movilidad Gratuita
# Oferta ya procesada: Asesor Call center ENTE L / SOLO 6hrs gestión , Con ó Sin Experiencia /Planilla Completa
# Oferta ya procesada: Movistar / Experta(a) en Reclutamiento y selección de personal / Sede Comas
# Oferta ya procesada: Ventas Entel / MINI FULL / Ingreso Directo SIN OJT /SOLO 6hrs y gana ¡1300 fijo + comisiones y más
# Oferta ya procesada: Movistar / Experta(a) en Reclutamiento y selección de personal / Sede Puente Piedra
# Oferta ya procesada: Movistar / Experta(a) en Reclutamiento y selección de personal / Sede San Isidro
# Oferta ya procesada: Movistar / Experta(a) en Reclutamiento y selección de personal / Sede Los Olivos
# Oferta extraída: Asistente Administrativo Trade / Santiago de Surco (Temporal)
# Oferta ya procesada: Operarios de limpieza sin experiencia para trabajar en Universidad de Miraflores
# Oferta ya procesada: Asesor Atención al cliente / Llamadas entrantes / Salario fijo de s/1300 + Planilla / Tu Elijes!
# Oferta ya procesada: Trabajo INME DIAT O/ Recibiendo Llamadas / Asesor Atención al cliente ENT EL!
# Oferta ya procesada: Ingeniero Electronico
# Oferta extraída: Impulsadora/Consultora/Productos de belleza/Campaña/Aruma Republica Dominicana
# Oferta extraída: Operarios limpieza varones para trabajar en gimnasio de San Isidro
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="7058B7B04BA9C46661373E686DCF3405" data-blind="false" id="7058B7B04BA9C46661373E686DCF3405" data-lc="ListOffers-Score-19" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Total de ofertas guardadas: 2364
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=170
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta extraída: Operarios limpieza para trabajar en gimnasio de San Isidro
# Oferta ya procesada: Buscamos Operarias de limpieza con experiencia para trabajar en Chilca
# Oferta ya procesada: Búsqueda masiva Operarias de limpieza con experiencia para trabajar en Chilca
# Oferta extraída: Técnico electronico
# Oferta extraída: Contador corporativo
# Oferta extraída: Plaza Vea Higuereta/Surco/Promotor de Ventas de Tarjetas OH! Con o/Sin Experiencia ¡PART TIME!
# Oferta extraída: Promotores retail experiencia en calzado, textil
# Oferta extraída: Chinawok Atocongo / Producción (área de cocina) /Full Time/Horario rotativo
# Oferta extraída: mall comas/ Claro/ turno mañana/ gana 1200 mas bonos s/1600 /descanso Rotativo
# Oferta extraída: Chinawok Atocongo / Buscamos Ayudante de cocina o Cocineros/Full /Horario rotativo
# Oferta ya procesada: Chinawok Atocongo / Producción (área de cocina) /Full Time/Horario rotativo
# Oferta extraída: Trabaja desde Casa!! Asesores Portabilidad Claro/ CON EXP/ Descanso fijo los Domingos / R E M O T O
# Oferta extraída: Docente virtual de Inglés Senati Ancash Chimbote
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="1530DA6B18F876AB61373E686DCF3405" data-blind="false" id="1530DA6B18F876AB61373E686DCF3405" data-lc="ListOffers-Score-13" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta extraída: Asesor Ventas /lunes a viernes de 09:30am a 6pm y sábados hasta las 2pm/1130+comisiones sin limite
# Oferta extraída: Asistente de Reposición y Mercadería Full Time Oechsle Salaverry
# Oferta extraída: Trabaja solo de Lun a Vie ¡Asesores de ventas!+Planilla+Pagos mensuales+Comisiones Ilimitadas+Bonos
# Oferta extraída: Caminante Lima Este / Lecturista de Medidores de Luz
# Oferta extraída: Técnico Electricista / Medicion Concentrada
# Oferta extraída: Trabaja de Lun a Vie ¡Asesores de ventas! Planilla+ Sueldo 1230+Pagos mensuales+Comisiones+Bonos
# Total de ofertas guardadas: 2380
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=171
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Trabaja solo de Lun a Vie ¡Asesores de ventas!+Planilla+Pagos mensuales+Comisiones Ilimitadas+Bonos
# Oferta ya procesada: Caminante Lima Este / Lecturista de Medidores de Luz
# Oferta ya procesada: Técnico Electricista / Medicion Concentrada
# Oferta ya procesada: Trabaja de Lun a Vie ¡Asesores de ventas! Planilla+ Sueldo 1230+Pagos mensuales+Comisiones+Bonos
# Oferta extraída: 15 Mecánica Soldador 3G Chincha Alta Minera
# Oferta ya procesada: Ayudante de cocina
# Oferta extraída: Atención al cliente vitrina Pastelería Tienda La Fontana
# Oferta extraída: Seguros Falabella / Asesor de Seguros Pachacutec VMT / Horario de oficina
# Oferta extraída: Seguros Falabella / Asesor Comercial Pachacutec VMT / Horario de oficina
# Oferta extraída: Técnico de Mantenimiento San Juan de Lurigancho
# Oferta ya procesada: Operarios de producción (Envasado y etiquetado)
# Oferta extraída: Asistente de Reclutamiento y Selección
# Oferta extraída: Multifuncional Mass Full Time San juan de Lurigancho y el Agustino
# Oferta extraída: Multifuncional Mass Full Time Lima (carapongo, chosica, lurigancho, cajamarquilla)
# Oferta ya procesada: Urgente! Agente De Seguridad Lima Sur/ Turno Mañana /Planilla Completa
# Oferta extraída: Personal de Seguridad Zona Lima Sur/ S/1500 Planilla Completa
# Oferta ya procesada: agente de seguridad / Beneficios completos + bonos adicionales
# Oferta extraída: Operarios(as) de Limpieza para Clínica en Pueblo libre, Av. Bolívar Con Sucre
# Oferta extraída: Impulsadora de productos Mifarma / Ate
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="7C0F0F7FCC961D6861373E686DCF3405" data-blind="false" id="7C0F0F7FCC961D6861373E686DCF3405" data-lc="ListOffers-Score-19" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Total de ofertas guardadas: 2391
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=172
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta extraída: Representante Médico Experiencia en Farmacia (Horizontal) // Bayer // Lima Campo
# Oferta extraída: Soporte tecnico/ full time turno tarde / Capa 11 días / gana hasta S/1475 /ATC/ ate
# Oferta ya procesada: Gana hasta S/ 1650.00 en ATC FT MAÑANA / Ate / Capa 11 días / Soporte técnico
# Oferta extraída: Atención al cliente/ Full Time PM / Call center/ Gana hasta S/1630/ Presencial San Isidro
# Oferta ya procesada: agente de seguridad / Beneficios completos + bonos adicionales
# Oferta extraída: Urgente / Supervisor HSE
# Oferta ya procesada: Personal de Seguridad Zona Lima Sur/ S/1500 Planilla Completa
# Oferta extraída: Químico Farmacéutico Asistente habilitado para Carabayllo
# Oferta extraída: Químico Farmacéutico Asistente habilitado para San Isidro
# Oferta extraída: Químico Farmacéutico Asistente habilitado para Chancay
# Oferta extraída: Técnica(o)s de Farmacia Av. Los Olivos!
# Oferta ya procesada: Personal de Seguridad Vial Lima Sur/ S/1400 Planilla Completa
# Oferta extraída: Agentes de Seguridad Vial Lima Sur/ S/1400 Planilla Completa
# Oferta extraída: Urgente!!! 30 Mercaderistas de ruta/Canal tradicional/Con/Sin experiencia
# Oferta extraída: Auxiliares de almacén/ operario/ con o sin experiencia / Turno mañana
# Oferta extraída: Supervisor(a) de ATC BCP
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="FFFDB4564EBA18C161373E686DCF3405" data-blind="false" id="FFFDB4564EBA18C161373E686DCF3405" data-lc="ListOffers-Score-16" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta extraída: Supervisor(a) Call Center BCP
# Oferta extraída: Analista Contable Operaciones/BCP
# Oferta extraída: Claro trabaja 7horas // gana mas de 1800//altas comisiones//bono de permanencia
# Total de ofertas guardadas: 2406
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=173
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Claro trabaja 7horas // gana mas de 1800//altas comisiones//bono de permanencia
# Oferta extraída: ¡Urgente!! Buscamos Operarios de Almacén / Sector Industrial / Puente Piedra y Lima Norte
# Oferta extraída: Asesor/a Outobund IO Senior / BCP / Molina
# Oferta extraída: Ejecutivo Comercial B2B, Huancayo
# Oferta extraída: Ejecutivo Comercial B2B, rubro alimentos , zona Lima
# Oferta extraída: Asesor comercial B2B, rubro distribución en Lima
# Oferta extraída: Ejecutivo comercial, rubro industrial en Surco
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="3977A27F88CD4ABF61373E686DCF3405" data-blind="false" id="3977A27F88CD4ABF61373E686DCF3405" data-lc="ListOffers-Score-7" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta extraída: ¡Urgente! Operario de producción c/s experiencia / horario rotativo / zona norte comas
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="58F7F256758D406161373E686DCF3405" data-blind="false" id="58F7F256758D406161373E686DCF3405" data-lc="ListOffers-Score-9" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta extraída: Capacitate en 3 días/ Asesores de Migraciones Perú Fibra Internet/Descanso Domingo
# Oferta ya procesada: Operario de Producción – Ingreso a planilla y beneficios
# Oferta extraída: Jefe de Marketing
# Oferta extraída: Promotora de belleza para ruta en tiendas retail (Saga, Ripley y Oechsle)
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="F313B5F94296C50161373E686DCF3405" data-blind="false" id="F313B5F94296C50161373E686DCF3405" data-lc="ListOffers-Score-14" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta extraída: Ingeniero de Planeamiento (Experiencia en Mantenimiento Retail) / San Isidro
# Oferta extraída: Vendedora Asesora de belleza con marcas de lujo para Oechsle Salaverry
# Oferta extraída: Ayudante de cocina / Mozos
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer outstanding" data-id="F78736F1A365AA2761373E686DCF3405" data-blind="false" id="F78736F1A365AA2761373E686DCF3405" data-lc="ListOffers-Score-18" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta ya procesada: Trabaja de 9 a 4 pm(solo 6 hrs y 1 h de break) y Descanso Domingos // Más de S/1200 al mes
# Total de ofertas guardadas: 2419
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=174
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Ayudante de cocina / Mozos
# Oferta extraída: Lider de Limpieza / Lima Centro
# Oferta ya procesada: Trabaja de 9 a 4 pm(solo 6 hrs y 1 h de break) y Descanso Domingos // Más de S/1200 al mes
# Oferta extraída: Atención! Asesor de ventas // Descanso Domingos // Más de S/1200 al mes
# Oferta extraída: Operario rubro gráfico
# Oferta extraída: Con y Sin experiencia/ Asesores Callcenter Claro/ Planilla Completa / Sueldo fijo, Comisiones y Bono
# Oferta extraída: Despacho de Combustible Av Ejercito con Juan de Aliaga
# Oferta extraída: Atento Asesor de ventas/42 hrs / L a V/SB y comisiones ilimitadas/ con o sin experiencia
# Oferta extraída: Trabajo Remoto/Full Time/PartTime/Claro Retenciones/Campaña Fácil turno tarde
# Oferta extraída: Full time mañana / Planilla Completa / ATC / Gana hasta S/1600/ Presencial en San Isidro
# Oferta extraída: Técnico Automotriz Motorizado
# Oferta extraída: Agente de Seguridad Armado Surquillo, San Juan de Miraflores
# Oferta ya procesada: A T C/ Híbrido/CHAT!! Full time Mañana,F I N A N C I E R A/Gana mas de s/. 1500/ contrato 1°dia
# Oferta extraída: Despacho de Combustible Republica de Panama con Aramburu + Bono de Pasajes S/100
# Oferta ya procesada: Atención al Cliente BBVA/Descanso Domingo con Horario de Oficina/Presencial en el Centro de Lima
# Oferta extraída: Atención al Cliente/ 10 días de Capacitación/7 Horas por la Tarde/Damos Movilidad
# Oferta extraída: Responsable de Planillas y Contraprestaciones
# Oferta extraída: Apoyo por el Día de la Madre
# Oferta extraída: Asesor Comercial Movistar Autorizado / Sueldo Fijo + Comisiones / Gana A Partir De La Primera Venta
# Oferta extraída: Despacho de Combustible Metro de Pershing
# Total de ofertas guardadas: 2435
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=175
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Asesor Comercial Movistar Autorizado / Sueldo Fijo + Comisiones / Gana A Partir De La Primera Venta
# Oferta ya procesada: Despacho de Combustible Metro de Pershing
# Oferta extraída: ¡¡Trabaja Solo de Lunes a Viernes con planilla completa desde el 1er día!!
# Oferta extraída: Despacho de Combustible Frente al Parque de las Aguas
# Oferta extraída: Trabaja Recibiendo Llamadas / Agentes Telefónicos / Atención al cliente ENT EL! Planilla Completa
# Oferta extraída: Médico/a
# Oferta extraída: Despacho de Combustible Av. Arriola Santa Catalina
# Oferta extraída: Asistente SOMA /Alicorp/ Planilla directa/ Utilidades
# Oferta extraída: Asesor de Atención al Cliente ¡Turno Mañana y Tarde! ¡Part Time y Full Time!
# Oferta ya procesada: Asistente Contable
# Oferta extraída: Atencion al Cliente/Part Time/Solo 4Hrs/6PM A 10PM/Sede Santa Anita/Sueldo Fijo+Planilla
# Oferta extraída: Auxiliar de almacen montacarga Lic A1 Lurin
# Oferta ya procesada: Operador de montacarga / Planilla directa / Horario rotativo / Pagos quincena y fin de mes
# Oferta extraída: Promotor telefonía Lima Metropolitana Sueldo + movilidad + comisiones + incentivos
# Oferta extraída: Asesor de Ventas American Eagle
# Oferta ya procesada: Supervisor de Producción ATE
# Oferta ya procesada: Supervisor de Almacén
# Oferta ya procesada: Jefe de Mantenimiento (Planta De Alimentos)
# Oferta extraída: Mercaderistas Moderno Consumo/ Ingresos Hasta S/1490 + Planilla Completa / Zona Centro
# Oferta ya procesada: Operarios de producción (Envasado y etiquetado)
# Total de ofertas guardadas: 2447
# Pasando a la siguiente página: None
# Procesando página: https://pe.computrabajo.com/empleos-en-lima?p=176
# No se encontró el pop-up.
# Encontradas 20 ofertas en esta página
# Oferta ya procesada: Supervisor de Almacén
# Oferta ya procesada: Jefe de Mantenimiento (Planta De Alimentos)
# Oferta ya procesada: Mercaderistas Moderno Consumo/ Ingresos Hasta S/1490 + Planilla Completa / Zona Centro
# Oferta ya procesada: Operarios de producción (Envasado y etiquetado)
# Oferta extraída: Home Office..!! Teleoperadores C/Sin Experiencia/Area de Ventas/Portabilidad
# Oferta extraída: Trabaja con o sin experiencia/ Asesor de ventas ¡Comisiones ilimitadas!
# Oferta ya procesada: Analista Jr. Planeamiento Financiero
# Oferta extraída: Trabaja 5 días a la semana/Back Office/ Planilla Completa
# Oferta extraída: Trabaja en Back office con o sin experiencia en el área/ Turno Mañana/ Planilla Completa
# Oferta extraída: Químico Farmacéutico control de calidad
# Oferta extraída: Ejecutivo de Ventas / Canto Grande
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="4D8D8A79E87594E461373E686DCF3405" data-blind="false" id="4D8D8A79E87594E461373E686DCF3405" data-lc="ListOffers-Score-11" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta extraída: SOLO Atención al Cliente / Llamadas entrantes/ Gana hasta los s/1400 /Planilla Completa
# Oferta extraída: Despacho de Combustible Centro Comercial Risso
# Error al procesar una oferta: Message: element click intercepted: Element <article class="box_offer" data-id="353D120C107D8FD161373E686DCF3405" data-blind="false" id="353D120C107D8FD161373E686DCF3405" data-lc="ListOffers-Score-14" data-offers-grid-offer-item-container="">...</article> is not clickable at point (405, 662). Other element would receive the click: <html xmlns="http://www.w3.org/1999/xhtml" lang="es-PE">...</html>
#   (Session info: chrome=131.0.6778.267)
# Stacktrace:
# 	GetHandleVerifier [0x0061FD53+23747]
# 	(No symbol) [0x005A7D54]
# 	(No symbol) [0x0047BE53]
# 	(No symbol) [0x004C5C57]
# 	(No symbol) [0x004C40C3]
# 	(No symbol) [0x004C1CCD]
# 	(No symbol) [0x004C1034]
# 	(No symbol) [0x004B5F57]
# 	(No symbol) [0x004E1DFC]
# 	(No symbol) [0x004B59A4]
# 	(No symbol) [0x004E2094]
# 	(No symbol) [0x004FB41E]
# 	(No symbol) [0x004E1B96]
# 	(No symbol) [0x004B3F3C]
# 	(No symbol) [0x004B4EBD]
# 	GetHandleVerifier [0x008FAC73+3017699]
# 	GetHandleVerifier [0x0090B93B+3086507]
# 	GetHandleVerifier [0x009040F2+3055714]
# 	GetHandleVerifier [0x006B5AF0+637536]
# 	(No symbol) [0x005B0A5D]
# 	(No symbol) [0x005ADA28]
# 	(No symbol) [0x005ADBC5]
# 	(No symbol) [0x005A07F0]
# 	BaseThreadInitThunk [0x75587BA9+25]
# 	RtlInitializeExceptionChain [0x7704C2EB+107]
# 	RtlClearBits [0x7704C26F+191]
#
# Oferta ya procesada: Operario de producción / Sueldo 1262 / Horario rotativo / Alimentación / Utilidades
# Oferta ya procesada: Urgente Técnico mecánico / Exp. en plantas industriales / Utilidades
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# Cell In[4], line 66, in main()
#      63     continue
#      65 offer.click()
# ---> 66 time.sleep(2)
#      68 detail_element = driver.find_element(By.CLASS_NAME, 'box_detail')
#      69 job_details[job_title] = detail_element.get_attribute('innerHTML')
#
# KeyboardInterrupt:
